# %%
import yfinance as yf
import pandas as pd

# %%
activestocks = pd.read_csv('./data/active stocks.csv')

# %%
activestocks.shape
# Out:
# (614, 1)

# %%
activestocks
# Out:
#         A
# 0      AA
# 1     AAL
# 2     AAP
# 3    AAPL
# 4    ABBV
# ..    ...
# 609   YUM
# 610   ZBH
# 611  ZBRA
# 612  ZION
# 613   ZTS
#
# [614 rows x 1 columns]

# %%
#listofstocks = activestocks.values.tolist()

# %%
names = activestocks['A'].tolist()

# %%
names
# Out:
# ['AA',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADCT',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALTR',
#  'ALXN',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANET',
#  'ANF',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ARNC',
#  'ASH',
#  'AT',
#  'ATI',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AYI',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBBY',
#  'BBY',
#  'BC',
#  'BDX',
#  'BEAM',
#  'BEN',
#  'BF_B',
#  'BHF',
#  'BIG',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BLL',
#  'BMY',
#  'BR',
#  'BRK_B',
#  'BSX',
#  'BTU',
#  'BUD',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
# ...

# %%
#stocks_download = yf.download(activestocks, 
#                     start='2019-01-01', 
#                      end='2019-12-31', 
#                      progress=False)
#stocks_download.head()

# %%
#tsla_df = yf.download('TSLA', 
#                     start='2019-01-01', 
#                     end='2019-12-31', 
#                      progress=False)
#tsla_df.head()

# %%
stocks = ['TSLA', 'AAPL']

# %%
type(stocks)
# Out:
# list

# %%
stocks_df = yf.download(names, 
                      start='2004-01-01', 
                      end='2021-03-17', 
                      progress=False)
stocks_df.head()
# Out:
# 2 Failed downloads:
# - BRK_B: No data found, symbol may be delisted
# - BF_B: No data found for this date range, symbol may be delisted
#             Adj Close                                                 \
#                    AA AAL        AAP      AAPL ABBV        ABC  ABMD
# Date
# 2004-01-02  72.434738 NaN  25.583614  0.325548  NaN  10.688442  7.00
# 2004-01-05  74.807442 NaN  25.351082  0.339163  NaN  11.050653  6.91
# 2004-01-06  74.248016 NaN  25.803566  0.337939  NaN  11.005128  6.99
# 2004-01-07  73.688583 NaN  26.614231  0.345589  NaN  11.112016  7.16
# 2004-01-08  74.575981 NaN  25.910389  0.357368  NaN  11.058571  7.29
#
#                                              ...      Volume              \
#                   ABT        ACN       ADBE  ...        XLNX         XOM
# Date                                         ...
# 2004-01-02  13.779174  19.398138  19.518400  ...   4629200.0  12180000.0
# ...

# %%
type(stocks_df)
# Out:
# pandas.core.frame.DataFrame

# %%
stocks_adjclose = stock_df['Adj Close']

# %%
stocks_adjclose.to_csv("./archive(1)/stocks_adjclose.csv")
